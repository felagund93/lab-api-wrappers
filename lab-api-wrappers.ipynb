# %% [markdown]
# # ![logo_ironhack_blue 7](https://user-images.githubusercontent.com/23629340/40541063-a07a0a8a-601a-11e8-91b5-2f13e4e6b441.png)
#
# # Lab | API wrappers - Create your collection of songs & audio features
#
#
# #### Instructions
#
#
# To move forward with the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster.
# The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="84acfa90a4b040b288565c9043c891fc",
                                                           client_secret="b2096cde0fb74a10a980ebcd67843f8a"))

# %%
playlist = sp.user_playlist_tracks("turgon1993", "44sPcoQ10on4NGGNtvsjI4")
playlist.keys()
#playlist['total']
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# We created the dictionary "Playlist". It is a dictionary which contains all the information from the playlist I requested, in a JSON format.

# %%
len(playlist['items'])
# Out:
# 91

# %% [markdown]
# We are interested in the items, which are the tracks in the playlist.

# %%
results = sp.user_playlist_tracks("turgon1993", "44sPcoQ10on4NGGNtvsjI4")
tracks = results['items']

while results['next']:
    results = sp.next(results)
    tracks.extend(results['items'])

#This while loop iterates over the playlist for every track 
#and appends the information of the tracks to the tracks list

#The tracks list is a list which contains different dictionaries

#One can access to the song titles like this:    
tracks[0]['track']['name']
# Out:
# 'Under Pressure - Remastered 2011'

# %%
len(tracks)
# Out:
# 91

# %%
#We get the artists participating in a song this way:
tracks[0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#   'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#   'id': '1dfeR4HaWDbWqFHLkxsg1d',
#   'name': 'Queen',
#   'type': 'artist',
#   'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0oSGxfWSnnOXhD2fKuz2Gy'},
#   'href': 'https://api.spotify.com/v1/artists/0oSGxfWSnnOXhD2fKuz2Gy',
#   'id': '0oSGxfWSnnOXhD2fKuz2Gy',
#   'name': 'David Bowie',
#   'type': 'artist',
#   'uri': 'spotify:artist:0oSGxfWSnnOXhD2fKuz2Gy'}]

# %%
#Manually get all the songs from the playlist
song_names=[]
i=0

while i < len(tracks):
    song_names.append(tracks[i]['track']['name'])
    i+=1
    
#song_names

# %% [markdown]
# ### Get info using functions

# %%
username="turgon1993"
playlist_id="44sPcoQ10on4NGGNtvsjI4"

# %%
def get_playlist_tracks(username, playlist_id):
    
    results = sp.user_playlist_tracks(username, playlist_id)
    tracks = results['items']
    
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    
    return tracks

# %%
def get_playlist_tracklist(username, playlist_id):
    
    results = sp.user_playlist_tracks(username, playlist_id)
    tracks = results['items']
    
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
        
    song_names=[]
    i=0

    while i < len(tracks):
        song_names.append(tracks[i]['track']['name'])
        i+=1
    
    return song_names

# %%
def get_artists_from_playlist(username,playlist_id):
    
    tracks_from_playlist = get_playlist_tracks(username, playlist_id)
    
    artists = []
    
    for track in tracks_from_playlist:
        artists_info = track['track']['artists']
        
        for artist_info in artists_info:
            artists.append(artist_info['name'])
    
    return list(set(artists))

# %%
artists_playlist=get_artists_from_playlist(username,playlist_id)
len(artists_playlist)
# Out:
# 68

# %%
def get_playlists(username):
    playlist_ids=[]
    i=0
    while i < len(sp.user_playlists(username)['items']):
        playlist_id=sp.user_playlists(username)['items'][i]['id']
        playlist_ids.append(playlist_id)
        i+=1
    return playlist_ids

# %%
turgon1993_playlists=get_playlists(username)

# %%
artists=sum([get_artists_from_playlist(username,playlist) for playlist in turgon1993_playlists], [])

# %%
len(artists)
# Out:
# 1554

# %%
clean = [x for x in artists if x != None]

# %%
len(clean)
# Out:
# 1554

# %%
def get_audio_features(artist):
    # get tracks from artist
    results = sp.search(q=f'artist:{artist}', limit=50)
    # extract the track ids
    track_ids = [track['id'] for track in results['tracks']['items']]
    song_names = [track['name'] for track in results['tracks']['items']]
    # extract the audio features
    audio_features = sp.audio_features(track_ids)
    # store audio features in a dataframe
    df = pd.DataFrame(audio_features)
    df['artist'] = artist
    df['song name'] = song_names
    return df

# %%
artists[13]
# Out:
# 'Mike Candys'

# %%
df_13=get_audio_features(artists[13])
df_13
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0

#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.397000    0.1210    0.616  126.063  audio_features
# 1           0.916000    0.0703    0.518  129.967  audio_features
# 2           0.369000    0.0997    0.537  125.989  audio_features
# 3           0.004310    0.0976    0.619  101.285  audio_features
# 4           0.472000    0.1340    0.322  126.016  audio_features
# 5           0.392000    0.2360    0.175  125.989  audio_features
# 6           0.000000    0.0599    0.458  126.030  audio_features
# 7           0.000020    0.3020    0.224  141.945  audio_features
# 8           0.478000    0.2010    0.476  126.042  audio_features
# 9           0.856000    0.0719    0.614  127.998  audio_features
# 10          0.882000    0.3760    0.397  135.009  audio_features
# 11          0.008690    0.1500    0.215  103.130  audio_features
# 12          0.000000    0.0946    0.399  127.972  audio_features
# 13          0.714000    0.0916    0.484  129.933  audio_features
# 14          0.000002    0.0613    0.328  134.950  audio_features
# 15          0.790000    0.1030    0.288  127.983  audio_features
# 16          0.000009    0.1530    0.452  127.007  audio_features
# 17          0.104000    0.3010    0.146  124.991  audio_features
# 18          0.000000    0.2720    0.739  104.967  audio_features
# 19          0.338000    0.6100    0.752  125.989  audio_features
# 20          0.794000    0.1170    0.782  125.909  audio_features
# 21          0.007240    0.0439    0.507  128.054  audio_features
# 22          0.097800    0.0868    0.245  141.989  audio_features
# 23          0.007880    0.1800    0.630  127.988  audio_features
# 24          0.016500    0.2480    0.392  126.048  audio_features
# 25          0.826000    0.4380    0.297  125.070  audio_features
# 26          0.000968    0.1460    0.493  138.610  audio_features
# 27          0.000113    0.1510    0.416  124.075  audio_features
# 28          0.000809    0.2190    0.547  125.001  audio_features
# 29          0.102000    0.3580    0.176  128.042  audio_features
# 30          0.000016    0.0615    0.701  127.967  audio_features
# 31          0.000000    0.1770    0.575  100.960  audio_features
# 32          0.787000    0.1030    0.352  128.006  audio_features
# 33          0.000133    0.1380    0.268  139.975  audio_features
# 34          0.362000    0.1460    0.221  126.027  audio_features
# 35          0.000010    0.1540    0.454  127.006  audio_features
# 36          0.743000    0.1040    0.223  123.961  audio_features
# 37          0.588000    0.3150    0.223  127.995  audio_features
# 38          0.000420    0.2150    0.620  125.022  audio_features
# 39          0.606000    0.4700    0.431  127.989  audio_features
# 40          0.000201    0.2400    0.388  135.087  audio_features
# 41          0.929000    0.1770    0.205  119.982  audio_features
# 42          0.066800    0.0720    0.538  126.020  audio_features
# 43          0.000000    0.2640    0.490  127.987  audio_features
# 44          0.689000    0.1020    0.366  127.993  audio_features
# 45          0.125000    0.1860    0.614  125.024  audio_features
# 46          0.563000    0.0858    0.581  125.997  audio_features
# 47          0.013900    0.1370    0.460  129.055  audio_features
# 48          0.000000    0.3620    0.380  126.033  audio_features
# 49          0.000000    0.1360    0.302  116.968  audio_features
#
#     time_signature       artist                                   song name
# 0                4  Mike Candys                                        Vibe
# 1                4  Mike Candys                                      Flexin
# 2                4  Mike Candys                                     Push It
# 3                3  Mike Candys                                    Overdose
# 4                4  Mike Candys                                   Like That
# 5                4  Mike Candys                           Insomnia - Rework
# 6                4  Mike Candys                  The Riddle Anthem - Rework
# 7                4  Mike Candys                                      Louder
# 8                4  Mike Candys                                        Boom
# 9                4  Mike Candys                                        Baby
# 10               4  Mike Candys                                      Raptor
# 11               3  Mike Candys                                   Love U So
# 12               4  Mike Candys   2012 (If the World Would End) - Radio Mix
# 13               4  Mike Candys                       Insomnia - Radio Edit
# 14               4  Mike Candys                                Lonely Again
# 15               4  Mike Candys                         Anubis - Radio Edit
# 16               4  Mike Candys              One Night in Ibiza - Radio Mix
# 17               4  Mike Candys                              Lights Go Down
# 18               4  Mike Candys                                 Coco Jamboo
# 19               4  Mike Candys                                    Oye Mami
# 20               4  Mike Candys                                     Selecta
# 21               4  Mike Candys                                  Pump It Up
# 22               4  Mike Candys                                    Darkness
# 23               4  Mike Candys                                 Cha Cha Cha
# 24               4  Mike Candys                                      Aliens
# 25               4  Mike Candys                         Something Like That
# 26               4  Mike Candys                              Dancing Around
# 27               4  Mike Candys  The Riddle Anthem - High n Wild Remix Edit
# 28               4  Mike Candys                               Give It to Me
# 29               4  Mike Candys                                 Begin Again
# 30               4  Mike Candys                      Everybody - Radio Edit
# 31               4  Mike Candys               Never Walk Alone - Radio Edit
# 32               4  Mike Candys                              All My Friends
# 33               4  Mike Candys                                         Sky
# 34               4  Mike Candys              Wellerman - Ravin' Whale Remix
# 35               4  Mike Candys              One Night in Ibiza - Radio Mix
# 36               4  Mike Candys                     La Serenissima - Rework
# 37               4  Mike Candys                                 Fiesta Loca
# 38               4  Mike Candys                         What's on Your Mind
# 39               4  Mike Candys                   Make It Home - Radio Edit
# 40               4  Mike Candys                                   Wellerman
# 41               4  Mike Candys                       Saltwater - Radio Mix
# 42               4  Mike Candys                                         Cry
# 43               4  Mike Candys                       Miracles - Radio Edit
# 44               4  Mike Candys                       Anubis - Original Mix
# 45               4  Mike Candys           Lights Go Down - Broke Remix Edit
# 46               4  Mike Candys               Like That - Original Club Mix
# 47               4  Mike Candys     Sunshine (Fly So High) - 2012 Radio Mix
# 48               4  Mike Candys              Last Man on Earth - Radio Edit
# 49               4  Mike Candys                                   Fireflies

# %%
df = pd.DataFrame()
error_log={'artist':[],'error':[]}

for artist in artists:
    #print("Getting features for:",artist)
    try:
        df_artist = get_audio_features(artist)
        df = pd.concat([df, df_artist])
    except Exception as e:
        #print("Error found:",e,"in artist",artist)
        error_log['artist'].append(artist)
        error_log['error'].append(e)
        # Logs the error appropriately. 
        continue
        
df = df.reset_index(drop=True)
error_log_df=pd.DataFrame(error_log)

# %%
df
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.745  0.7710    7    -4.051     1       0.0967       0.00543
# 1             0.718  0.8590    0    -3.603     1       0.0417       0.29600
# 2             0.724  0.9150    5    -3.358     1       0.1610       0.09750
# 3             0.605  0.9010    4    -5.141     0       0.0837       0.04730
# 4             0.774  0.8080   11    -5.206     0       0.0544       0.05300
# ...             ...     ...  ...       ...   ...          ...           ...
# 71925         0.306  0.4160    4   -20.363     0       0.0435       0.62200
# 71926         0.451  0.5850    2   -13.421     0       0.0505       0.17700
# 71927         0.576  0.8860    8    -8.534     1       0.0505       0.22400
# 71928         0.445  0.6750    2    -7.965     1       0.0349       0.01200
# 71929         0.652  0.0987    0   -19.058     1       0.2930       0.56800
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000000    0.1540    0.701  124.005  audio_features
# 1              0.000000    0.3980    0.757  120.041  audio_features
# 2              0.000638    0.3130    0.518  120.045  audio_features
# 3              0.000000    0.3980    0.546  123.990  audio_features
# 4              0.002210    0.1230    0.264  112.896  audio_features
# ...                 ...       ...      ...      ...             ...
# 71925          0.898000    0.0748    0.913   81.589  audio_features
# 71926          0.324000    0.0905    0.155  110.028  audio_features
# 71927          0.004310    0.1250    0.326  131.953  audio_features
# 71928          0.029800    0.1470    0.311  134.075  audio_features
# 71929          0.000000    0.2220    0.484  132.448  audio_features
#
#                            id                                   uri  \
# 0      0wpEtERZ78hweuJCWD9eAE  spotify:track:0wpEtERZ78hweuJCWD9eAE
# 1      5Av85j2myp1Zcp7ICKDN4P  spotify:track:5Av85j2myp1Zcp7ICKDN4P
# 2      7l33AaaNrYHcr0kjzNiBUf  spotify:track:7l33AaaNrYHcr0kjzNiBUf
# 3      5aavp5BSNuKzqpq11m34fi  spotify:track:5aavp5BSNuKzqpq11m34fi
# 4      4ETYOkzLdLBHGqy05q5a8e  spotify:track:4ETYOkzLdLBHGqy05q5a8e
# ...                       ...                                   ...
# 71925  25HFZB3SgFI1zEOeURx17w  spotify:track:25HFZB3SgFI1zEOeURx17w
# 71926  7AIgqX0acXyzkOs64ahhrm  spotify:track:7AIgqX0acXyzkOs64ahhrm
# 71927  3NfAAwntISr3hmJ01n5Yrw  spotify:track:3NfAAwntISr3hmJ01n5Yrw
# 71928  2igdn18wrfICzkiD6zHLpb  spotify:track:2igdn18wrfICzkiD6zHLpb
# 71929  4HrGDpAKkviP6qqmEptMPW  spotify:track:4HrGDpAKkviP6qqmEptMPW
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/0wpEtERZ78hw...
# 1      https://api.spotify.com/v1/tracks/5Av85j2myp1Z...
# 2      https://api.spotify.com/v1/tracks/7l33AaaNrYHc...
# 3      https://api.spotify.com/v1/tracks/5aavp5BSNuKz...
# 4      https://api.spotify.com/v1/tracks/4ETYOkzLdLBH...
# ...                                                  ...
# 71925  https://api.spotify.com/v1/tracks/25HFZB3SgFI1...
# 71926  https://api.spotify.com/v1/tracks/7AIgqX0acXyz...
# 71927  https://api.spotify.com/v1/tracks/3NfAAwntISr3...
# 71928  https://api.spotify.com/v1/tracks/2igdn18wrfIC...
# 71929  https://api.spotify.com/v1/tracks/4HrGDpAKkviP...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/0wpE...       163209
# 1      https://api.spotify.com/v1/audio-analysis/5Av8...       162000
# 2      https://api.spotify.com/v1/audio-analysis/7l33...       164750
# 3      https://api.spotify.com/v1/audio-analysis/5aav...       151452
# 4      https://api.spotify.com/v1/audio-analysis/4ETY...       161090
# ...                                                  ...          ...
# 71925  https://api.spotify.com/v1/audio-analysis/25HF...       101435
# 71926  https://api.spotify.com/v1/audio-analysis/7AIg...       233336
# 71927  https://api.spotify.com/v1/audio-analysis/3NfA...       206563
# 71928  https://api.spotify.com/v1/audio-analysis/2igd...       281200
# 71929  https://api.spotify.com/v1/audio-analysis/4HrG...       466747
#
#        time_signature       artist                                 song name
# 0                   4      Tiscore                             Fire To Smoke
# 1                   4      Tiscore                          The Tide Is High
# 2                   4      Tiscore                                      Down
# 3                   4      Tiscore              Fire To Smoke - Yves V Remix
# 4                   4      Tiscore  Where The Roses Grow - VIZE & NOØN Remix
# ...               ...          ...                                       ...
# 71925               4  Andrew Zack                                 Fur Elise
# 71926               4  Andrew Zack                              Requiem Deus
# 71927               4  Andrew Zack                                   Shimmer
# 71928               4  Andrew Zack                               Here We Are
# 71929               3  Andrew Zack              Tell Me Why / Back in Kokomo
#
# [71930 rows x 20 columns]

# %%
df.to_csv('./song_features.csv')

# %%
error_log_df.head()
# Out:
#                     artist                                              error
# 0                 Sam Gray          'NoneType' object has no attribute 'keys'
# 1           Rebecca Helena  Length of values (0) does not match length of ...
# 2                Agent Zed  Length of values (0) does not match length of ...
# 3  The Lyndhurst Orchestra  Length of values (0) does not match length of ...
# 4                    Cream          'NoneType' object has no attribute 'keys'

# %% [markdown]
# ### Approach for Error Handling:

# %% [markdown]
# Do not run the loop for the entire list at once. Instead, do it in a "fractioned" way. In the case here, run the loop with get_audio_features() for the first 300 elements, then 300-600, and so on in groups of 300 elements until the last element of the list. This is going to let me avoid running the whole loop every time, especially if it is prone to crash at some point in the middle of it.

# %% [markdown]
# With this approach, if I lose data I will only lose about 300 elements of it, which is much faster to debug and run again than doing it for the whole code every time.

# %%
len(artists)
# Out:
# 1554

# %%
art_1=artists[0:300]
art_2=artists[301:600]
art_3=artists[601:900]
art_4=artists[901:1200]
art_5=artists[1201:]

# %%
def get_features_artist_list(list_artists):
    df = pd.DataFrame()
    error_log={'artist':[],'error':[]}

    for artist in list_artists:
        #print("Getting features for:",artist)
        try:
            df_artist = get_audio_features(artist)
            df = pd.concat([df, df_artist])
        except Exception as e:
            #print("Error found:",e,"in artist",artist)
            error_log['artist'].append(artist)
            error_log['error'].append(e)
            # Logs the error appropriately. 
            continue

    df = df.reset_index(drop=True)
    error_log_df=pd.DataFrame(error_log)
    
    return df, error_log_df

# %%
df_1, err_log_1 = get_features_artist_list(art_1)

# %%
df_1.head()
err_log_1
# Out:
#                     artist                                              error
# 0                 Sam Gray          'NoneType' object has no attribute 'keys'
# 1           Rebecca Helena  Length of values (0) does not match length of ...
# 2                Agent Zed  Length of values (0) does not match length of ...
# 3  The Lyndhurst Orchestra  Length of values (0) does not match length of ...
# 4                    Cream          'NoneType' object has no attribute 'keys'
# 5                    Cream          'NoneType' object has no attribute 'keys'
